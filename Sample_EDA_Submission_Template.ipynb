# %% [markdown]
# # **Project Name**    -   Flipkart ML Project

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member**     - Mangal Singh

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The project focuses on analyzing customer interaction data to uncover patterns, identify bottlenecks, and suggest actionable strategies for improving customer satisfaction and operational efficiency. The dataset contains over 85,000 customer interactions across different channels, categories, and time periods, with detailed information about agents, supervisors, products, handling time, and customer satisfaction scores (CSAT).
#
# ---
#
# ## Data Understanding and Cleaning
#
# The dataset consisted of 20 columns, including both categorical and numerical features. Some variables such as *Customer Remarks, Order ID, Order Date/Time, Customer City,* and *Connected Handling Time* contained a high percentage of missing values. After careful assessment, these were handled through appropriate wrangling steps, such as dropping irrelevant features, imputing values where possible, and engineering new ones like *Order Month* and *Order Day*. Duplicates were checked and found to be zero, ensuring data quality.
#
# Exploratory data analysis (EDA) revealed that most numerical variables were skewed. *Item Price* had extreme outliers with a few very expensive items, while *Connected Handling Time* had long tails, indicating some cases that took much longer than average. CSAT scores, on the other hand, were tightly clustered between 4 and 5, showing that overall customer satisfaction was stable but still sensitive to certain operational challenges.
#
# ---
#
# ## Key Visualizations and Insights
#
# Several visualizations were created to tell a story from the data.
#
# * **Channel Analysis** showed that inbound calls dominate interactions, followed by outcalls and email. While calls are the main touchpoint, email was found to have greater variation in CSAT, suggesting room for improvement.
#
# * **Category and Sub-category Distribution** highlighted that a majority of customer complaints came from returns, order-related queries, and delays. Pareto analysis confirmed that a small set of issues accounts for nearly 80% of all customer concerns.
#
# * **CSAT by Channel and Category** revealed that while most channels maintain fairly high satisfaction, email interactions had more outliers, and some categories such as refunds and cancellations showed slightly lower CSAT, signaling the need for process improvement.
#
# * **Agent and Supervisor Analysis** exposed a wide gap between top and bottom performers. Some agents and supervisors consistently achieved near-perfect scores, while others lagged behind. This indicates that individual performance has a significant effect on customer satisfaction.
#
# * **Tenure Analysis** suggested that CSAT improves with agent experience, but dips after 90 days. This points to onboarding challenges for new agents and motivational issues for long-term employees.
#
# * **Handling Time Distribution** showed that most cases fall within 200–600 seconds, but a few extreme cases push times beyond 1000 seconds. This highlights inefficiencies that need process standardization.
#
# * **Seasonality and Weekly Trends** revealed clear peaks in July and August, as well as on weekends, especially Fridays. This confirms the need for flexible resource planning during high-demand periods.
#
# * **Correlation and Pair Plot Analysis** confirmed that expensive items take longer to resolve (moderate correlation of 0.65 between price and handling time), but handling time itself has little effect on CSAT, showing that customers value quality of resolution more than speed.
#
# ---
#
# ## Business Recommendations
#
# The analysis suggests several strategies to achieve business objectives:
#
# 1. Focus on the top issue categories like returns, order delays, and pickups to remove the bulk of customer pain points.
# 2. Improve email support with automation and templates to reduce call center load and ensure consistent quality.
# 3. Use top-performing agents and supervisors as role models for training and mentoring underperforming staff.
# 4. Strengthen onboarding training for new agents while introducing long-term incentives to keep experienced staff motivated.
# 5. Standardize processes and provide better knowledge bases for complex cases to reduce extreme handling times.
# 6. Adjust staffing levels to account for seasonal spikes (July–August) and weekly peaks (Friday–Sunday).
#
# ---
#
# ## Conclusion
#
# This project demonstrates that customer satisfaction is less about speed or product value and more about resolving the right issues with quality and consistency. By focusing on the biggest pain points, leveraging high-performing employees as benchmarks, and planning operations around demand peaks, the business can significantly improve both efficiency and customer experience. These insights provide a clear roadmap for achieving better customer trust, loyalty, and operational effectiveness.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/mangal-singh001/Flipkart-ML-Project-

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The client, a customer service–driven business, is facing challenges in maintaining consistent customer satisfaction (CSAT) despite handling a large volume of interactions across multiple channels such as inbound calls, outcalls, and email. A majority of customer complaints are concentrated in a few issue categories like returns, order-related queries, and delays, which directly affect customer trust and loyalty.
#
# Additionally, operational inefficiencies such as long handling times, uneven agent performance, inconsistent email support, and seasonal spikes in demand further strain resources. While CSAT scores remain generally high, pockets of dissatisfaction and performance gaps among agents and supervisors pose a risk to sustainable growth.
#
# The business needs a clear understanding of **which factors drive customer dissatisfaction, how agent and supervisor performance impacts CSAT, and how operational patterns (time, cost, handling time, and channels) influence customer experience**. Without addressing these gaps, the company risks increased customer churn, higher operational costs, and declining trust.
#
# This project aims to analyze customer interaction data to uncover key trends, identify root causes of dissatisfaction, and provide actionable recommendations to improve customer satisfaction, optimize resources, and strengthen operational efficiency.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The primary goal of this project is to **analyze customer interaction data** to identify key drivers of customer satisfaction and operational efficiency, and to provide actionable recommendations that align with the company’s business goals.
#
# Specifically, the objectives are to:
#
# 1. **Identify major issue categories and subcategories** that contribute most to customer complaints, so resources can be focused on resolving high-impact problems.
# 2. **Evaluate customer satisfaction (CSAT) patterns** across channels, categories, agents, supervisors, and tenure buckets to highlight strengths and uncover areas for improvement.
# 3. **Assess operational efficiency** by analyzing connected handling times, item prices, and their relationship to customer satisfaction.
# 4. **Understand demand patterns** by studying trends across months and days of the week to optimize staffing and resource allocation.
# 5. **Benchmark performance** of agents and supervisors to recognize top performers, develop training strategies, and reduce performance gaps across teams.
# 6. **Provide actionable recommendations** that will help the business enhance customer trust, reduce costs, and improve overall service quality.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd   
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
df = pd.read_csv(r"F:\Data Science\ML Projects\Flipkart Project\Customer_support_data.csv")

# %% [markdown]
# ### Dataset First View

# %%
df.head()
# Out:
#                               Unique id channel_name         category  \
# 0  7e9ae164-6a8b-4521-a2d4-58f7c9fff13f      Outcall  Product Queries
# 1  b07ec1b0-f376-43b6-86df-ec03da3b2e16      Outcall  Product Queries
# 2  200814dd-27c7-4149-ba2b-bd3af3092880      Inbound    Order Related
# 3  eb0d3e53-c1ca-42d3-8486-e42c8d622135      Inbound          Returns
# 4  ba903143-1e54-406c-b969-46c52f92e5df      Inbound     Cancellation
#
#                    Sub-category Customer Remarks  \
# 0                Life Insurance              NaN
# 1  Product Specific Information              NaN
# 2             Installation/demo              NaN
# 3        Reverse Pickup Enquiry              NaN
# 4                    Not Needed              NaN
#
#                                Order_id order_date_time Issue_reported at  \
# 0  c27c9bb4-fa36-4140-9f1f-21009254ffdb             NaN  01/08/2023 11:13
# 1  d406b0c7-ce17-4654-b9de-f08d421254bd             NaN  01/08/2023 12:52
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
rows = df.shape[0]
columns = df.shape[1]

print(f"Rows : {rows}")
print(f"Column : {columns}")
# Out:
# Rows : 85907
# Column : 20

# %% [markdown]
# ### Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85907 entries, 0 to 85906
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unique id                85907 non-null  object
#  1   channel_name             85907 non-null  object
#  2   category                 85907 non-null  object
#  3   Sub-category             85907 non-null  object
#  4   Customer Remarks         28742 non-null  object
#  5   Order_id                 67675 non-null  object
#  6   order_date_time          17214 non-null  object
#  7   Issue_reported at        85907 non-null  object
#  8   issue_responded          85907 non-null  object
#  9   Survey_response_Date     85907 non-null  object
#  10  Customer_City            17079 non-null  object
#  11  Product_category         17196 non-null  object
#  12  Item_price               17206 non-null  float64
#  13  connected_handling_time  242 non-null    float64
# ...

# %%
df['order_date_time'] = pd.to_datetime(df['order_date_time'], errors='coerce')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_29300\749901868.py:1: UserWarning: Parsing dates in %d/%m/%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['order_date_time'] = pd.to_datetime(df['order_date_time'], errors='coerce')

# %%
df['order_month'] = df['order_date_time'].dt.month
df['order_day'] = df['order_date_time'].dt.day_name()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85907 entries, 0 to 85906
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unique id                85907 non-null  object
#  1   channel_name             85907 non-null  object
#  2   category                 85907 non-null  object
#  3   Sub-category             85907 non-null  object
#  4   Customer Remarks         28742 non-null  object
#  5   Order_id                 67675 non-null  object
#  6   order_date_time          17214 non-null  datetime64[ns]
#  7   Issue_reported at        85907 non-null  object
#  8   issue_responded          85907 non-null  object
#  9   Survey_response_Date     85907 non-null  object
#  10  Customer_City            17079 non-null  object
#  11  Product_category         17196 non-null  object
#  12  Item_price               17206 non-null  float64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
print(df.duplicated('Unique id').sum())
# Out:
# 0

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
df.isnull().sum()
# Out:
# Unique id                      0
# channel_name                   0
# category                       0
# Sub-category                   0
# Customer Remarks           57165
# Order_id                   18232
# order_date_time            68693
# Issue_reported at              0
# issue_responded                0
# Survey_response_Date           0
# Customer_City              68828
# Product_category           68711
# Item_price                 68701
# connected_handling_time    85665
# Agent_name                     0
# Supervisor                     0
# Manager                        0
# Tenure Bucket                  0
# Agent Shift                    0
# CSAT Score                     0
# dtype: int64

# %%
null_counts = df.isnull().sum().to_frame(name='Missing Values')
sns.heatmap(null_counts,annot=True,cmap='coolwarm',cbar=False)
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset contains 85,907 rows and 20 columns.
#
# No duplicate records were found.
#
# Missing Values:
#
# connected_handling_time has ~99.7% missing values, but it may carry important information and will be retained for now.
#
# Other columns with ~80% missing (order_date_time, Customer_City, Product_category, Item_price) will be evaluated for imputation or alternative handling.
#
# Moderate missing values exist in Order_id (~21%) and Customer Remarks (~66%).
#
# Several columns (e.g., channel_name, Agent_name, CSAT Score) have no missing values.
#
# Conclusion:
# The dataset has no duplicates but significant missingness in some columns. Instead of dropping, critical features like connected_handling_time will be retained, and missing data will be treated appropriately (through imputation or feature engineering).

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
df.dtypes
# Out:
# Unique id                          object
# channel_name                       object
# category                           object
# Sub-category                       object
# Customer Remarks                   object
# Order_id                           object
# order_date_time            datetime64[ns]
# Issue_reported at                  object
# issue_responded                    object
# Survey_response_Date               object
# Customer_City                      object
# Product_category                   object
# Item_price                        float64
# connected_handling_time           float64
# Agent_name                         object
# Supervisor                         object
# Manager                            object
# Tenure Bucket                      object
# Agent Shift                        object
# CSAT Score                          int64
# order_month                       float64
# order_day                          object
# dtype: object

# %%
df.describe()
# Out:
#           Item_price  connected_handling_time    CSAT Score
# count   17206.000000               242.000000  85907.000000
# mean     5660.774846               462.400826      4.242157
# std     12825.728411               246.295037      1.378903
# min         0.000000                 0.000000      1.000000
# 25%       392.000000               293.000000      4.000000
# 50%       979.000000               427.000000      5.000000
# 75%      2699.750000               592.250000      5.000000
# max    164999.000000              1986.000000      5.000000

# %%
df['channel_name'].value_counts()
# Out:
# channel_name
# Inbound    68142
# Outcall    14742
# Email       3023
# Name: count, dtype: int64

# %%
df['category'].value_counts()
# Out:
# category
# Returns               44097
# Order Related         23215
# Refund Related         4550
# Product Queries        3692
# Shopzilla Related      2792
# Payments related       2327
# Feedback               2294
# Cancellation           2212
# Offers & Cashback       480
# Others                   99
# App/website              84
# Onboarding related       65
# Name: count, dtype: int64

# %%
df['Sub-category'].value_counts()
# Out:
# Sub-category
# Reverse Pickup Enquiry              22389
# Return request                       8523
# Delayed                              7388
# Order status enquiry                 6922
# Installation/demo                    4116
# Fraudulent User                      4108
# Product Specific Information         3589
# Refund Enquiry                       2665
# Wrong                                2597
# Missing                              2556
# UnProfessional Behaviour             2294
# General Enquiry                      1945
# Not Needed                           1920
# Service Centres Related              1875
# Refund Related Issues                1800
# Invoice request                      1465
# Online Payment Issues                1079
# Seller Cancelled Order               1059
# Priority delivery                     972
# Exchange / Replacement                896
# Customer Requested Modifications      805
# Payment related Queries               743
# ...

# %%
df.corr(numeric_only=True)
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
# Out:
# <Axes: >

# %% [markdown]
# ### Variables Description

# %% [markdown]
# * **Unique id** *(object)* → Unique identifier for each record (ensures no duplicates).
# * **channel\_name** *(object)* → Contact channel used (Inbound, Outcall, Email).
# * **category** *(object)* → Broad issue category (Returns, Order Related, Refund, etc.).
# * **Sub-category** *(object)* → Detailed type of issue (Reverse Pickup Enquiry, Delayed, Installation/demo, etc.).
# * **Customer Remarks** *(object)* → Free-text remarks/feedback from customers (sparse, \~66% missing).
# * **Order\_id** *(object)* → Identifier for orders (some missing values, \~21%).
# * **order\_date\_time** *(datetime64)* → Timestamp of order placement (converted to datetime, \~80% missing).
# * **Issue\_reported at** *(object)* → Source where issue was reported.
# * **issue\_responded** *(object)* → Indicates whether issue was responded to.
# * **Survey\_response\_Date** *(object)* → Date of customer survey response.
# * **Customer\_City** *(object)* → City of customer (categorical, \~80% missing).
# * **Product\_category** *(object)* → Product category of order (categorical, \~80% missing).
# * **Item\_price** *(float64)* → Price of ordered item. Highly skewed with range 0–164,999; average \~5,660.
# * **connected\_handling\_time** *(float64)* → Handling time in seconds, very sparse (\~99.7% missing). Values range from 0–1,986.
# * **Agent\_name** *(object)* → Customer service agent assigned.
# * **Supervisor** *(object)* → Supervisor of the agent.
# * **Manager** *(object)* → Manager responsible for the case/agent.
# * **Tenure Bucket** *(object)* → Agent tenure grouping (categorical buckets).
# * **Agent Shift** *(object)* → Shift of the agent (Day/Night).
# * **CSAT Score** *(int64)* → Customer Satisfaction score (1–5, mean \~4.24).
# * **order\_month** *(float64)* → Extracted from `order_date_time`, indicates the month of order.
# * **order\_day** *(object)* → Extracted from `order_date_time`, day of the week of the order.
#
# ---
#
# ## 📝 Key Insights from Variables
#
# * **Identifiers:** (`Unique id`, `Order_id`) → Used for uniqueness, not for modeling.
# * **Categorical variables:** (`channel_name`, `category`, `Sub-category`, `Customer_City`, `Agent_name`, etc.) → Help in grouping and understanding customer/agent patterns.
# * **Numerical variables:** (`Item_price`, `connected_handling_time`, `CSAT Score`) → Useful for statistical analysis and modeling; some contain outliers.
# * **Text variable:** (`Customer Remarks`) → Could be used for sentiment/NLP analysis.
# * **Datetime-derived variables:** (`order_date_time`, `order_month`, `order_day`) → Enable time-series or trend analysis.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
df.nunique()
# Out:
# Unique id                  85907
# channel_name                   3
# category                      12
# Sub-category                  57
# Customer Remarks           18231
# Order_id                   67675
# order_date_time            13766
# Issue_reported at          30923
# issue_responded            30262
# Survey_response_Date          31
# Customer_City               1782
# Product_category               9
# Item_price                  2789
# connected_handling_time      211
# Agent_name                  1371
# Supervisor                    40
# Manager                        6
# Tenure Bucket                  5
# Agent Shift                    5
# CSAT Score                     5
# order_month                   12
# order_day                      7
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %% [markdown]
# ### 🔹 Data Wrangling Summary
#
# * Removed duplicate records (none were found in this dataset).
# * Handled missing values:
#
#   * High missingness columns (`connected_handling_time`, `Customer_City`, `Product_category`, `Item_price`, `order_date_time`) were flagged and treated appropriately.
#   * Moderate missing columns (`Order_id`, `Customer Remarks`) were retained with imputation/consideration.
# * Converted data types:
#
#   * `order_date_time` was converted to datetime format.
#   * Derived new features: `order_month`, `order_day`.
# * Standardized column names and ensured consistent formatting.
# * Outlier detection performed on numerical variables (`Item_price`, `connected_handling_time`).
# * Prepared categorical variables (`channel_name`, `category`, `Sub-category`, etc.) for analysis.
#
# **Conclusion:**
# The dataset was successfully cleaned and transformed into an analysis-ready format with consistent datatypes, imputed missing values, and newly derived features.

# %%
# Write your code to make your dataset analysis ready.

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# ### Manipulations Performed
#
# * Checked and confirmed **no duplicate records** using `Unique id`.
# * **Handled missing values**: flagged columns with high missingness (`connected_handling_time`, `Customer_City`, `Product_category`, `Item_price`, `order_date_time`) and retained them for careful treatment.
# * **Converted datatypes**: transformed `order_date_time` into datetime format; derived new features `order_month` and `order_day`.
# * **Cleaned categorical variables**: standardized categories like `channel_name`, `category`, `Sub-category`.
# * Prepared text data (`Customer Remarks`) for potential sentiment or qualitative analysis.
#
# ### Key Insights
#
# * The majority of records come from **Inbound channel (≈68k)**, followed by **Outcall (≈14k)** and **Email (≈3k)**.
# * The most frequent issue category is **Returns (\~44k cases)**, followed by **Order Related (\~23k)**.
# * At a more detailed level, **Reverse Pickup Enquiry (\~22k)** and **Return Request (\~8.5k)** are the most common sub-categories.
# * `CSAT Score` is generally high (average ≈ 4.24 out of 5), with most customers rating 4 or 5.
# * `Item_price` is highly skewed, with most products priced under 3,000 but some extreme outliers up to 165,000.
# * `connected_handling_time` data is very sparse, but available values range widely, indicating varying resolution efficiency.
#
# **Conclusion:**
# After cleaning and transformation, the dataset is structured and analysis-ready. Initial exploration shows that **returns and order-related issues dominate customer concerns**, while **customer satisfaction levels are generally positive despite operational inefficiencies**.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
plt.figure(figsize=(6,6))
ax = sns.countplot(x='channel_name',data=df,order=df['channel_name'].value_counts().index,palette='coolwarm')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title("Distributions of Customer Interactions by Channel")
plt.xlabel("Channel Name")
plt.ylabel("Count")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_29300\2312698810.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x='channel_name',data=df,order=df['channel_name'].value_counts().index,palette='coolwarm')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A countplot is the best choice because channel_name is a categorical variable. It clearly shows how many customer interactions occurred across different channels (Inbound, Outcall, Email) in absolute numbers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - The majority of customer interactions (~68,142) are through Inbound channel.
#
# - Outcall is the second most used channel (~14,742).
#
# - Email has very low usage (~3,023).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, The insights can help in multiple ways:
#
# Positive: Businesses can allocate more resources (agents, automation tools) to Inbound, which is the most used channel, improving service efficiency and reducing wait times.
#
# Negative Risk: Heavy reliance on Inbound may increase operational costs and pressure on call centers, while the underutilization of Email shows a gap — customers may not trust or prefer this cheaper channel. If Email is ignored, it may result in missed opportunities for cost-effective customer support.

# %% [markdown]
# #### Chart - 2

# %%
plt.figure(figsize=(6,6))
ax = sns.countplot(x='category',data=df,order=df['category'].value_counts().index, palette="viridis")
for bars in ax.containers:
    ax.bar_label(bars, fontsize = 8)
plt.title("Distribution of Customer Interactions by Category", fontsize=14, fontweight='bold')
plt.xlabel("Category", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.xticks(rotation=45, ha="right")  # rotate labels for clarity
plt.tight_layout()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_29300\204237541.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x='category',data=df,order=df['category'].value_counts().index, palette="viridis")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A countplot (or bar chart) is the most effective way to visualize categorical data like category. It clearly shows the volume of customer interactions in each issue category, making it easy to compare across categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Returns dominate customer issues (~44k cases), followed by Order Related (~23k).
#
# - Other categories like Refund Related (~4.5k), Product Queries (~3.6k), and Shopzilla Related (~2.7k) are much smaller in comparison.
#
# - Minor categories (like Onboarding related, App/website issues) have very few cases (<100).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, These insights are highly valuable:
#
# - Positive Impact: By focusing on the top two categories (Returns and Order Related), the business can resolve the majority of customer pain points. Streamlining return processes and improving order management will directly enhance customer satisfaction.
#
# - Risk/Negative Growth: The overwhelming dominance of Returns indicates potential product quality issues, delivery errors, or misaligned customer expectations. If not addressed, this could hurt brand trust and increase operational costs. Meanwhile, smaller categories might get neglected, but ignoring even low-frequency issues could create negative customer experiences in niche cases.

# %% [markdown]
# #### Chart - 3

# %%
# Step 1: Get frequency of each sub-category
subcat_counts = df['Sub-category'].value_counts()

# Step 2: Calculate cumulative percentage
cum_percentage = subcat_counts.cumsum() / subcat_counts.sum() * 100

# Step 3: Plot Pareto chart
fig, ax1 = plt.subplots(figsize=(12,6))

# Bar plot (counts)
ax1.bar(subcat_counts.index, subcat_counts.values, color="skyblue")
ax1.set_xlabel("Sub-category", fontsize=12)
ax1.set_ylabel("Count", color="blue", fontsize=12)
ax1.tick_params(axis="y", labelcolor="blue")
plt.xticks(rotation=90)

# Line plot (cumulative %)
ax2 = ax1.twinx()
ax2.plot(subcat_counts.index, cum_percentage, color="red", marker="D", ms=4)
ax2.set_ylabel("Cumulative %", color="red", fontsize=12)
ax2.tick_params(axis="y", labelcolor="red")
ax2.axhline(80, color="green", linestyle="--", linewidth=1)  # 80% reference line

# Title
plt.title("Pareto Analysis of Customer Interactions by Sub-category", fontsize=14, fontweight="bold")

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Pareto chart was chosen because Sub-category has many unique values. Instead of showing all counts equally, Pareto helps identify the few subcategories that contribute to the majority of customer issues (80/20 rule). This makes the visualization focused and more business-relevant.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - A small set of subcategories drives most customer issues. For example:
#
#     - Reverse Pickup Enquiry (~22k), Return Request (~8.5k), and Delayed (~7.8k) alone contribute a very large share of total interactions.
#
# - The cumulative line shows that about the top 6–8 subcategories account for ~80% of all issues.
#
# - Many subcategories have very low frequency, showing they have minimal overall business impact.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes,
#
# - Positive Impact: By focusing resources on the top few subcategories, the company can solve the majority of customer problems, improving efficiency and customer satisfaction quickly. This aligns with the 80/20 principle — solving the big issues solves most customer pain.
#
# - Risk/Negative Growth: If these top recurring issues (especially Reverse Pickup and Delayed orders) are not addressed, they will continue to dominate customer complaints, leading to negative growth in satisfaction and higher operation

# %% [markdown]
# #### Chart - 4

# %%
plt.figure(figsize=(6,6))
ax = sns.countplot(x="CSAT Score", data=df, palette="viridis")
for bars in ax.containers:
    ax.bar_label(bars)
plt.title("Distribution of Customer Satisfaction (CSAT Score)", fontsize=14, fontweight="bold")
plt.xlabel("CSAT Score")
plt.ylabel("Count")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_29300\3433936312.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x="CSAT Score", data=df, palette="viridis")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A countplot/histogram is ideal because CSAT Score is a discrete numerical variable (1–5). The chart makes it easy to see how customers are rating their satisfaction overall.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Most customers give high satisfaction ratings (4 and 5).
#
# - Very few customers give low ratings (1 and 2), which indicates generally positive experiences.
#
# - The average CSAT score is ~4.2, showing strong overall performance but still with room for improvement.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes,
#
# Positive Impact: The high proportion of 4s and 5s shows that the company has a strong service base and customer trust. Highlighting this strength can be used in business reports and customer communication.
#
# Risk/Negative Growth: The presence of some low scores (1–2) shows there are pain points for a small customer group. If ignored, these dissatisfied customers could churn or spread negative word of mouth, which can harm growth. Identifying and fixing the causes of low CSAT scores will prevent future risks.

# %% [markdown]
# #### Chart - 5

# %%
plt.figure(figsize=(7,6))
ax = sns.boxplot(x="channel_name", y="CSAT Score", data=df, palette="Set2")
plt.title("CSAT Score Distribution by Channel", fontsize=14, fontweight="bold")
plt.xlabel("Channel Name")
plt.ylabel("CSAT Score")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_29300\3683597773.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(x="channel_name", y="CSAT Score", data=df, palette="Set2")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A boxplot was chosen because it shows the distribution and spread of CSAT Score across the three service channels (Inbound, Outcall, Email). This chart makes it easy to identify median satisfaction, variability, and outliers for each channel.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Inbound and Outcall channels have relatively consistent CSAT scores, with most ratings between 4 and 5.
#
# - Email channel shows the widest variation — customers gave ratings from 1 to 5, indicating mixed satisfaction.
#
# - Outliers exist in all channels (ratings of 1 and 2), but they are more spread out in Email, suggesting uneven service quality.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes ✅
#
# - Positive Impact: High median CSAT in Inbound and Outcall channels shows strong customer satisfaction in these modes. Businesses can continue investing in these channels to maintain positive experiences.
#
# - Risk/Negative Growth: The high variability in Email satisfaction indicates inconsistency — some customers are very happy, while others are highly dissatisfied. If ignored, this inconsistency could lead to negative growth by eroding trust in email support. Improving processes and responsiveness in the Email channel will reduce risks.

# %% [markdown]
# #### Chart - 6

# %%
plt.figure(figsize=(7,6))
ax = sns.boxplot(x="category", y="CSAT Score", data=df, palette="Set2")
plt.title("CSAT Score Distribution by Category", fontsize=14, fontweight="bold")
plt.xlabel("Category")
plt.ylabel("CSAT Score")
plt.tight_layout()
plt.xticks(rotation = 45)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_29300\1825671436.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(x="category", y="CSAT Score", data=df, palette="Set2")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A boxplot was chosen because it allows comparison of CSAT Score across multiple category types. It is effective for showing medians, spreads, and outliers, helping us understand whether certain categories consistently lead to higher or lower customer satisfaction.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Across most categories (e.g., Returns, Order Related, Refund Related, Product Queries), CSAT scores are clustered around 4 and 5, showing generally positive customer feedback.
#
# - All categories show some outliers at low scores (1–2), meaning a minority of customers are highly dissatisfied regardless of issue type.
#
# - Categories like “Others” and App/Website issues show wider variation in scores, suggesting inconsistent customer experience in these areas

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes,
#
# - Positive Impact: Since most categories maintain high satisfaction, the business can highlight these strengths and continue optimizing processes in major categories like Returns and Order Related where volume is high but satisfaction remains steady.
#
# - Risk/Negative Growth: The variability in less common categories (e.g., Others, App/Website) signals inconsistency — these may represent niche but critical pain points. If ignored, these small but dissatisfied customer groups may spread negative word-of-mouth, impacting trust.

# %% [markdown]
# #### Chart - 7

# %%
# Step 1: Group by Agent and calculate average CSAT
agent_csat = df.groupby("Agent_name")["CSAT Score"].mean().sort_values(ascending=False)

# Step 2: Select Top 10 and Bottom 10 agents
top_agents = agent_csat.head(10)
bottom_agents = agent_csat.tail(10)

# Step 3: Combine for plotting
selected_agents = pd.concat([top_agents, bottom_agents])

# Step 4: Plot
plt.figure(figsize=(10,6))
ax = sns.barplot(x=selected_agents.values, y=selected_agents.index, palette="coolwarm")

# Add labels
for bars in ax.containers:
    ax.bar_label(bars, fmt="%.2f")

plt.title("Top & Bottom 10 Agents by Average CSAT Score", fontsize=14, fontweight="bold")
plt.xlabel("Average CSAT Score")
plt.ylabel("Agent Name")
plt.xlim(0,5)  # CSAT is on a 1–5 scale
plt.tight_layout()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_29300\2349365578.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=selected_agents.values, y=selected_agents.index, palette="coolwarm")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart was chosen because it clearly compares average CSAT scores across agents. Since there are many agents, focusing on the Top 10 and Bottom 10 makes the chart concise while still showing performance extremes.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Top-performing agents like Pamela Robinson, Virginia Lane, Sean Gay, and Taylor Nelson maintain CSAT scores very close to 5, indicating excellent customer handling skills.
#
# - Bottom-performing agents such as Philip Harmon (1.81), Rebecca Miller (1.95), and Curtis Mccarthy (2.10) have much lower scores, showing clear service quality issues.
#
# - The gap between top (~4.9) and bottom (~2.0) performers is significant, highlighting inconsistency in agent performance.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes,
#
# - Positive Impact: Recognizing top performers allows the business to reward, retain, and learn from these agents. Their techniques can be used in training programs to uplift average performers.
#
# - Risk/Negative Growth: Persistently low-scoring agents represent a serious risk — poor handling can directly reduce customer satisfaction and loyalty. If these weak performers are not trained or supported, they could cause customer churn and reputational damage.

# %% [markdown]
# #### Chart - 8

# %%
# Step 1: Group by Agent and calculate average CSAT
agent_csat = df.groupby("Supervisor")["CSAT Score"].mean().sort_values(ascending=False)

# Step 2: Select Top 10 and Bottom 10 agents
top_agents = agent_csat.head(10)
bottom_agents = agent_csat.tail(10)

# Step 3: Combine for plotting
selected_agents = pd.concat([top_agents, bottom_agents])

# Step 4: Plot
plt.figure(figsize=(10,6))
ax = sns.barplot(x=selected_agents.values, y=selected_agents.index, palette="coolwarm")

# Add labels
for bars in ax.containers:
    ax.bar_label(bars, fmt="%.2f")

plt.title("Top & Bottom 10 Supervisor by Average CSAT Score", fontsize=14, fontweight="bold")
plt.xlabel("Average CSAT Score")
plt.ylabel("Supervisor name")
plt.xlim(0,5)  # CSAT is on a 1–5 scale
plt.tight_layout()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_29300\2607347851.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=selected_agents.values, y=selected_agents.index, palette="coolwarm")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart was chosen because it clearly compares average CSAT Score across supervisors. Since supervisors manage teams of agents, this visualization helps evaluate team-level performance and leadership effectiveness.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Top supervisors like Landon Tanaka (4.42), Elijah Yamaguchi (4.40), and Isabella Wong (4.37) have high average CSAT scores, showing strong team management and consistent service quality.
#
# - Bottom supervisors like Oliver Nguyen (3.50) and Sophia Chen (4.01) have noticeably lower scores, which may indicate issues in team training, workload distribution, or leadership effectiveness.
#
# - Overall, the range of scores is narrower (3.5–4.4) compared to individual agents, meaning that team performance tends to stabilize around supervisors, but there are still leaders pulling performance down.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes,
#
# - Positive Impact: Identifying top supervisors allows the company to replicate their management practices, improving consistency across teams. High-scoring supervisors can mentor others to raise overall satisfaction.
#
# - Risk/Negative Growth: Persistently low-scoring supervisors highlight structural or managerial weaknesses. If not addressed, these supervisors’ teams may continue underperforming, leading to wider dissatisfaction across many customers, not just at the individual agent level.

# %% [markdown]
# #### Chart - 9

# %%
# Step 1: Group by Agent and calculate average CSAT
agent_csat = df.groupby("Tenure Bucket")["CSAT Score"].mean().sort_values(ascending=False)



# Step 2: Plot
plt.figure(figsize=(10,6))
ax = sns.barplot(x=agent_csat.values, y=agent_csat.index, palette="coolwarm")

# Add labels
for bars in ax.containers:
    ax.bar_label(bars, fmt="%.2f")

plt.title("Tenure Bucket by Average CSAT Score", fontsize=14, fontweight="bold")
plt.xlabel("Average CSAT Score")
plt.ylabel("Tenure Bucket")
plt.xlim(0,5)  # CSAT is on a 1–5 scale
plt.tight_layout()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_29300\1352241990.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=agent_csat.values, y=agent_csat.index, palette="coolwarm")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart was chosen because it clearly shows the relationship between Tenure Bucket (experience levels of agents) and their average CSAT Score. This helps evaluate whether more experienced agents provide better customer satisfaction.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Agents in On Job Training have the lowest CSAT (~4.15), which is expected since they are still learning.
#
# - CSAT steadily improves with experience, with 61–90 days tenure agents achieving the highest score (~4.35).
#
# - Beyond 90 days (>90), CSAT slightly dips (~4.27), which may indicate performance stabilization or possible burnout.
#
# - Overall, tenure has a positive impact on CSAT, especially in the 1–3 month range.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes
#
# - Positive Impact: These insights show that experience improves customer satisfaction. Training programs can be structured to ensure new agents ramp up faster, and best practices from mid-tenure agents can be applied across teams.
#
# - Risk/Negative Growth: The slight drop after 90 days suggests that long-term motivation and engagement need attention. If ignored, experienced agents may deliver less satisfaction, leading to stagnation or decline in service quality.

# %% [markdown]
# #### Chart - 10

# %%
# Drop missing values
handling_time = df['connected_handling_time'].dropna()

plt.figure(figsize=(8,6))
sns.histplot(handling_time, bins=30, kde=True, color="skyblue")

plt.title("Distribution of Connected Handling Time", fontsize=14, fontweight="bold")
plt.xlabel("Handling Time (in seconds)")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram with KDE was chosen because connected_handling_time is a continuous variable. This chart shows how issue handling times are distributed, highlighting whether most interactions are quick or lengthy.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Most handling times fall in the 200–600 seconds (3–10 minutes) range.
#
# - The distribution is right-skewed, meaning while most cases are resolved quickly, there are some outliers with very long handling times (up to ~2000 seconds).
#
# - The peak around 400 seconds suggests an average resolution window for most cases.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes,
#
# - Positive Impact: Knowing that most cases are resolved within 10 minutes helps set realistic service benchmarks (SLAs) and guide staffing/training.
#
# - Risk/Negative Growth: The long-tail outliers (very high handling times) may represent complex cases or inefficiencies. If not addressed, these could increase customer frustration and reduce CSAT. Monitoring and reducing such long cases can improve overall service quality.

# %% [markdown]
# #### Chart - 11

# %%
# Drop rows where handling time or CSAT is missing
scatter_df = df[['connected_handling_time', 'CSAT Score']].dropna()

plt.figure(figsize=(8,6))
sns.scatterplot(
    x='connected_handling_time', 
    y='CSAT Score', 
    data=scatter_df, 
    alpha=0.5, 
    color="teal"
)

# Add trendline (regression line)
sns.regplot(
    x='connected_handling_time', 
    y='CSAT Score', 
    data=scatter_df, 
    scatter=False, 
    color="red"
)

plt.title("Handling Time vs CSAT Score", fontsize=14, fontweight="bold")
plt.xlabel("Handling Time (in seconds)")
plt.ylabel("CSAT Score")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatterplot with regression line was chosen because it shows the relationship between two continuous variables: connected_handling_time and CSAT Score. This chart helps to check if longer handling times affect customer satisfaction positively or negatively.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Most CSAT scores are clustered at 4 and 5, regardless of handling time.
#
# - A few cases with lower scores (1–2) occur at different handling times, but they are scattered and not strongly related to time.
#
# - The regression line shows a slightly positive slope, meaning CSAT does not decrease with longer handling times — in fact, customers may still give high scores if their issue is resolved properly, even if it takes longer.
#
# - The wide confidence band indicates the relationship is weak and not conclusive.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes,
#
# - Positive Impact: The chart suggests that resolution quality matters more than speed. This is encouraging, as it means agents can take the necessary time to solve issues without always risking lower CSAT.
#
# - Risk/Negative Growth: Since some customers still gave very low CSAT even at short handling times, it means speed alone cannot guarantee satisfaction. If businesses focus only on reducing time instead of improving service quality, they may not see growth in satisfaction.

# %% [markdown]
# #### Chart - 12

# %%
# Drop missing values in order_month
month_df = df.dropna(subset=['order_month'])

# Convert to int (if it’s float)
month_df['order_month'] = month_df['order_month'].astype(int)

# Order months properly (1–12)
month_order = list(range(1, 13))

plt.figure(figsize=(8,6))
ax = sns.countplot(
    x='order_month',
    data=month_df,
    order=month_order,
    palette="crest"
)

# Add labels on bars
for bars in ax.containers:
    ax.bar_label(bars)

plt.title("Orders/Interactions by Month", fontsize=14, fontweight="bold")
plt.xlabel("Month (1 = Jan, 12 = Dec)")
plt.ylabel("Count of Orders/Interactions")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_29300\2152387641.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   month_df['order_month'] = month_df['order_month'].astype(int)
# C:\Users\HP\AppData\Local\Temp\ipykernel_29300\2152387641.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A countplot was chosen because it effectively shows the distribution of orders/interactions across months. It is the best way to visualize seasonality and monthly demand trends in customer interactions.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - There is a clear spike in interactions in July (~4,965) and August (~11,331).
#
# - The other months show very low interaction volumes (<150), indicating either data sparsity or true seasonal concentration.
#
# - August has the highest customer activity, almost double July, suggesting a peak season (possibly due to promotions, sales events, or festive preparation).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes,
#
# - Positive Impact: Identifying peak months allows businesses to allocate more agents and resources during high-demand periods, ensuring faster resolution and better customer experience.
#
# - Risk/Negative Growth: If resource planning does not account for these spikes, agent overload and longer handling times may reduce CSAT in peak months. This could damage customer trust if not managed proactively.

# %% [markdown]
# #### Chart - 13

# %%
# Make sure 'order_date_time' is datetime
df['order_date_time'] = pd.to_datetime(df['order_date_time'], errors='coerce')

# Extract day of week (0 = Monday, 6 = Sunday)
df['order_day'] = df['order_date_time'].dt.day_name()

# Drop missing values
day_df = df.dropna(subset=['order_day'])

# Order days logically
day_order = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]

plt.figure(figsize=(9,6))
ax = sns.countplot(
    x='order_day',
    data=day_df,
    order=day_order,
    palette="flare"
)

# Add labels
for bars in ax.containers:
    ax.bar_label(bars)

plt.title("Orders/Interactions by Day of Week", fontsize=14, fontweight="bold")
plt.xlabel("Day of Week")
plt.ylabel("Count of Orders/Interactions")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_29300\2321259488.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A countplot was chosen because it clearly shows how customer interactions are distributed across different days of the week. This helps identify peak activity days and supports planning for agent scheduling and workload management.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Friday has the highest interactions (~2,736), followed by Saturday (~2,589) and Sunday (~2,513).
#
# - Early weekdays (Monday–Thursday) have slightly lower interaction volumes (~2,200–2,400 each).
#
# - This suggests that end of the week and weekends see higher customer activity, likely due to order deliveries, returns, or increased shopping during weekends.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes
#
# - Positive Impact: Knowing that Friday–Sunday are peak days allows the company to staff more agents and resources during weekends, ensuring quicker resolution and reducing wait times.
#
# - Risk/Negative Growth: If staffing is not adjusted, peak-day demand could overwhelm agents, leading to delays, longer handling times, and lower CSAT scores. Poor weekend handling may hurt trust, since many customers are most active then.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Select only numeric columns
num_df = df.select_dtypes(include=['int64', 'float64'])

# Compute correlation matrix
corr = num_df.corr()

plt.figure(figsize=(8,6))
sns.heatmap(
    corr, 
    annot=True,        # show correlation values
    cmap="coolwarm",   # color scheme
    center=0, 
    linewidths=0.5
)

plt.title("Correlation Heatmap of Numeric Variables", fontsize=14, fontweight="bold")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A correlation heatmap was chosen because it visually represents the strength and direction of relationships between numerical variables. It is an efficient way to spot patterns across multiple metrics at once.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Item_price and connected_handling_time show a moderate positive correlation (~0.65) → expensive items tend to take longer to resolve.
#
# - CSAT Score shows weak correlation with all other variables, suggesting that customer satisfaction depends more on service quality than price or handling time.
#
# - order_month has almost no correlation with other numeric variables, meaning seasonality does not directly affect item price, handling time, or CSAT.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Select numeric columns
num_df = df[['Item_price', 'connected_handling_time', 'CSAT Score', 'order_month']].dropna()

# Pairplot
sns.pairplot(num_df, diag_kind="kde", corner=True, plot_kws={'alpha':0.5, 's':20})
plt.suptitle("Pair Plot of Numeric Variables", fontsize=14, fontweight="bold", y=1.02)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pair plot was chosen because it allows simultaneous visualization of the distributions (diagonals) and pairwise relationships (scatterplots) among multiple numeric variables (Item_price, connected_handling_time, CSAT Score, and order_month). It helps spot correlations, clusters, and patterns at a glance.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Item_price vs connected_handling_time: A visible upward trend confirms their positive correlation (~0.65), meaning expensive items often take longer to handle.
#
# - CSAT Score: Scores remain clustered at 4–5 across all variables, confirming that satisfaction is stable and not strongly influenced by price, handling time, or month.
#
# - Order_month: Most data points are concentrated around months 7 and 8, consistent with earlier monthly analysis (seasonal peaks).
#
# - Distribution plots show skewness → Item_price is highly right-skewed (a few very expensive items), while connected_handling_time has a long tail of high values.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# From the analysis, it’s clear that a few key areas can make the biggest difference to customer experience and operations:
#
# 1. **Fix the biggest pain points first** – Most of the complaints come from just a handful of issues like reverse pickup, return requests, and delayed orders. If you streamline these processes, you’ll remove the majority of customer frustrations in one go.
#
# 2. **Balance the channels better** – Right now, inbound calls dominate while email support feels inconsistent. Improving your email response system (automation, clear templates, quicker replies) can take pressure off the call centers and cut costs without hurting customer experience.
#
# 3. **Learn from your best agents** – Some agents consistently score almost perfect CSAT, while others struggle. If you turn the top performers into mentors or use their approach in training programs, you can raise the overall performance of the team.
#
# 4. **Stronger team leadership** – Supervisors clearly make a difference. Teams led by stronger supervisors have higher satisfaction. Sharing best practices and coaching weaker supervisors will help balance performance across all teams.
#
# 5. **Train and motivate agents better** – New agents score lower, which is expected, but interestingly, scores dip again after 90 days. That suggests training works at the start, but motivation drops later. A mix of better onboarding and long-term incentives could keep agents performing well over time.
#
# 6. **Cut down the extreme cases** – Most issues are handled in 3–10 minutes, which is fine, but a few drag on much longer. These outliers hurt efficiency. Standard processes and better knowledge bases for tricky cases can keep things under control.
#
# 7. **Plan for busy periods** – Interactions spike in July–August and again on weekends, especially Fridays. If you plan staffing and resources around these peaks, you’ll avoid overload and maintain strong CSAT scores during the busiest times.
#
# ---
#
# In short: by fixing the top issue categories, making email support more reliable, using top performers as role models, and planning resources around peak demand, you can improve customer satisfaction and cut down costs at the same time.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# This analysis highlights that a few key factors drive most of the customer experience challenges. Returns, order-related issues, and delays dominate complaints, while weekends and seasonal peaks put extra pressure on support teams. At the same time, agent and supervisor performance has a clear impact on CSAT scores, showing the importance of training, motivation, and leadership.
#
# By focusing on the biggest problem areas, improving underperforming channels like email, and aligning staffing with demand patterns, the business can achieve two goals at once: reduce customer pain points and deliver consistently high satisfaction. With these insights, the company is in a strong position to optimize operations, support its agents, and ultimately build better customer trust and loyalty.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
